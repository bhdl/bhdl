# %%
(+ 1 2)

# %%
(list (pict:circle 10) (list (pict:rectangle 20 30) (list (pict:circle 20))))

# %%
;; logging is not working in obvious ways
(log-warning "hello")
(current-logger)
(require racket/logging)
(with-logging-to-port (current-output-port)
                      (lambda () (log-info "info"))
                      'warning)

# %% [markdown]
# # Testing #lang

# %%
#lang iracket/lang #:require racket/base #:reader scribble/reader

# %%
(define xs @list[1 2 3])

# %% [markdown]
# now switch back to racket syntax and reader

# %%
#lang iracket/lang #:require racket

# %% [markdown]
# # Debug the easyeda importer

# %%
#lang iracket/lang #:require bhdl/splicing #:reader bhdl/splicing
(list (list 1 2 3) ..)
(putenv "BHDL_LIBRARY_PATH" "~/bhdl/bhdl-footprints")
(getenv "BHDL_LIBRARY_PATH")
(require racket/list
         racket/format
         (prefix-in pict: pict))

# %%
(require "../bhdl-lib/bhdl/private/fp-easyeda.rkt")

# %%
(list 1 2)
# Out:
# '(1 2)

# %%
(uuid->fp "bd8c6c64dc7b4d18806bb8859f9f2606")
# Out:
# DEBUG:  unrecognized shape:  HOLE
# DEBUG:  unrecognized shape:  HOLE
# DEBUG:  unrecognized shape:  HOLE
# DEBUG:  unrecognized shape:  HOLE
# DEBUG:  unrecognized shape:  HOLE
# '#s(footprint (#s(line-spec -6.999986000000007 -5.999988000000002 -6.999986000000007 -6.999985999999993 0.150114) #s(line-spec -6.999986000000007 -6.999985999999993 -5.999988000000002 -6.999985999999993 0.150114) #s(line-spec -5.999988000000002 6.999986000000007 -6.999986000000007 6.999986000000007 0.150114) #s(line-spec -6.999986000000007 6.999986000000007 -6.999986000000007 5.999988000000016 0.150114) #s(line-spec 6.999986000000007 5.999988000000016 6.999986000000007 6.999986000000007 0.150114) #s(line-spec 6.999986000000007 6.999986000000007 5.999988000000002 6.999986000000007 0.150114) #s(line-spec 5.999988000000002 -6.999985999999993 6.999986000000007 -6.999985999999993 0.150114) #s(line-spec 6.999986000000007 -6.999985999999993 6.999986000000007 -5.999988000000002 0.150114) #s(line-spec -6.8999100000000055 6.8999100000000055 6.8999100000000055 6.8999100000000055 0.150114) #s(line-spec 6.8999100000000055 -6.899909999999991 -6.8999100000000055 -6.899909999999991 0.150114) #s(line-spec 6.8999100000000055 -6.899909999999991 6.8999100000000055 6.8999100000000055 0.150114) #s(line-spec -6.8999100000000055 6.8999100000000055 -6.8999100000000055 -6.899909999999991 0.150114) #s(line-spec -7.499858000000003 -7.499857999999989 7.499857999999989 -7.499857999999989 0.150114) #s(line-spec 7.499857999999989 -7.499857999999989 7.499857999999989 7.499858000000003 0.150114) #s(line-spec 7.499857999999989 7.499858000000003 -7.499858000000003 7.499858000000003 0.150114) #s(line-spec -7.499858000000003 7.499858000000003 -7.499858000000003 -7.499857999999989 0.150114)) (#s(pad-spec "1" 6.290056000000007 -5.079999999999998 smd rect (2.549906 2.499868) (0 0)) #s(pad-spec "2" -7.560056000000003 -2.539999999999992 smd rect (2.549906 2.499868) (0 0))))

# %%
(uuid->fp "c14472e271ba4df3b94818d49fecaa9f")
# Out:
# requesting https://easyeda.com/api/components/c14472e271ba4df3b94818d49fecaa9f ..
# DEBUG:  unrecognized shape:  ARC
# DEBUG:  unrecognized shape:  ARC
# DEBUG:  unrecognized shape:  ARC
# DEBUG:  unrecognized shape:  ARC
# DEBUG:  unrecognized shape:  CIRCLE
# DEBUG:  unrecognized shape:  ARC
# DEBUG:  unrecognized shape:  ARC
# DEBUG:  unrecognized shape:  ARC
# DEBUG:  unrecognized shape:  ARC
# DEBUG:  unrecognized shape:  CIRCLE
# DEBUG:  unrecognized shape:  HOLE
# DEBUG:  unrecognized shape:  HOLE
# DEBUG:  unrecognized shape:  HOLE
# DEBUG:  unrecognized shape:  HOLE
# DEBUG:  unrecognized shape:  HOLE
# '#s(footprint (#s(line-spec -7.6200000000000045 -2.5400000000000773 -7.6200000000000045 0.44449999999994816 0.508) #s(line-spec -7.747000000000071 -5.080000000000041 -7.747000000000071 -7.747000000000071 0.4064) #s(line-spec -7.747000000000071 -7.747000000000071 -5.080000000000155 -7.747000000000071 0.4064) #s(line-spec -5.080000000000155 -7.747000000000071 -5.080000000000155 -7.747000000000071 0.4064) #s(line-spec -5.080000000000155 7.746999999999957 -7.683500000000095 7.746999999999957 0.4064) #s(line-spec -7.683500000000095 7.746999999999957 -7.747000000000071 7.746999999999957 0.4064) #s(line-spec -7.747000000000071 7.746999999999957 -7.747000000000071 7.683499999999867 0.4064) #s(line-spec -7.747000000000071 7.683499999999867 -7.747000000000071 5.079999999999927 0.4064) #s(line-spec -1.084071999999992 6.05155000000002 1.11582199999998 6.05155000000002 0.09999979999999999) #s(line-spec 1.11582199999998 6.05155000000002 1.11582199999998 4.05155400000001 0.09999979999999999) #s(line-spec 1.11582199999998 4.05155400000001 -1.084071999999992 4.05155400000001 0.09999979999999999) #s(line-spec -1.084071999999992 4.05155400000001 -1.084071999999992 6.05155000000002 0.09999979999999999) #s(line-spec 0.2158999999999196 5.851651999999945 0.4157979999999952 5.851651999999945 0.24999949999999996) #s(line-spec 0.4157979999999952 5.851651999999945 0.